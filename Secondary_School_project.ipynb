# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaeljane/Secondary-school-data-analysis/blob/main/Secondary_School_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #import standard library 

#data analysis
import pandas as pd
import numpy as np


#plotting
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px
# Read csv
df=pd.read_csv("/content/Secpndary School Clear Data.csv")

# %%
# read top rows
df.head()
# Out:
#      Region  ... Total number of beds
# 0  Region 1  ...                 61.0
# 1  Region 1  ...                430.0
# 2  Region 1  ...                215.0
# 3  Region 1  ...                  0.0
# 4  Region 1  ...                  0.0
#
# [5 rows x 89 columns]

# %%
# print rows and columns 
df.shape
# Out:
# (1445, 89)

# %%
#summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 89 columns):
#  #   Column                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                             --------------  -----
#  0   Region                                                                                                                             1445 non-null   object
#  1   Name of County                                                                                                                     1445 non-null   object
#  2   Name of Sub- County                                                                                                                1445 non-null   object
# ...

# %%
# name of the columns 
df.columns.values
# Out:
# array(['Region', 'Name of County', 'Name of Sub- County',
#        'Name of School', 'School Code (MoE)', "School's P.O. Box number",
#        'What is the school category',
#        'What is the gender of the students?',
#        'What form of accommodation does the school operate?',
#        'Type of school', 'Location of school',
#        'Did the school receive any funding in the year 2017 or 2018?',
#        'Total income for 2018: ', 'Total income for 2017: ',
#        'How many KCSE candidates did the school have in 2018?',
#        'What was the overall school mean score in 2018?',
#        'What was MATHEMATICS  mean score in 2018?',
#        'What was the ENGLISH  mean score in 2018?',
#        'What was PHYSICS  mean score in 2018?',
#        'What was CHEMISTRY  mean score in 2018?',
#        'What was BIOLOGY  mean score in 2018?',
#        'How many KCSE candidates did the school have in 2017?',
#        'What was the overall school mean score in 2017?',
# ...

# %%
# Data types of columns
df.dtypes
# Out:
# Region                                       object
# Name of County                               object
# Name of Sub- County                          object
# Name of School                               object
# School Code (MoE)                            object
#                                              ...
# Total enrolment of boarders                 float64
# Total Dormitory Floor area                  float64
# Temporary Dormitory                         float64
# Inadequate and overcrowded  dormitories     float64
# Total number of beds                        float64
# Length: 89, dtype: object

# %%
#check null value 
df.isnull().sum()
# Out:
# Region                                       0
# Name of County                               0
# Name of Sub- County                          0
# Name of School                               0
# School Code (MoE)                           62
#                                             ..
# Total enrolment of boarders                  1
# Total Dormitory Floor area                   2
# Temporary Dormitory                          1
# Inadequate and overcrowded  dormitories      5
# Total number of beds                         6
# Length: 89, dtype: int64

# %%
#summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 89 columns):
#  #   Column                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                             --------------  -----
#  0   Region                                                                                                                             1445 non-null   object
#  1   Name of County                                                                                                                     1445 non-null   object
#  2   Name of Sub- County                                                                                                                1445 non-null   object
# ...

# %%
# drop unique identifier
df.drop(df.columns[[3, 4, 5]], axis=1, inplace=True)
df.head()
# Out:
#      Region  ... Total number of beds
# 0  Region 1  ...                 61.0
# 1  Region 1  ...                430.0
# 2  Region 1  ...                215.0
# 3  Region 1  ...                  0.0
# 4  Region 1  ...                  0.0
#
# [5 rows x 86 columns]

# %%
#missing values as a percent of observations
df.shape
# Out:
# (1445, 86)

# %%
min_count = int(((100-20)/100) *df.shape[0] + 1)

# %%
df = df.dropna(axis=1, thresh=min_count)

# %%
df.shape
# Out:
# (1445, 77)

# %%
# row_min_count = int(((5)/100) * df.shape[0] + 1)
df = df.dropna(thresh=len(df.columns)-1)
df.shape
# Out:
# (1207, 77)

# %%
print(row_min_count)
print(min_count)
print(len(df.columns)-1)
# Out:
# 73
# 1157
# 76

# %%
#check null value 
df.isnull().sum()
# Out:
# Region                                      0
# Name of County                              0
# Name of Sub- County                         0
# What is the school category                 0
# What is the gender of the students?         0
#                                            ..
# Total enrolment of boarders                 0
# Total Dormitory Floor area                  0
# Temporary Dormitory                         0
# Inadequate and overcrowded  dormitories     0
# Total number of beds                        0
# Length: 77, dtype: int64

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#      Region  ... Does the region experience any inter/intra community conflicts or attacks?
# 3  Region 1  ...                                                 No
# 4  Region 1  ...                                                 No
# 5  Region 1  ...                                                 No
# 6  Region 1  ...                                                Yes
# 7  Region 1  ...                                                Yes
#
# [5 rows x 30 columns]

# %%
obj_df.dtypes
# Out:
# Region                                                                                                                               object
# Name of County                                                                                                                       object
# Name of Sub- County                                                                                                                  object
# What is the school category                                                                                                          object
# What is the gender of the students?                                                                                                  object
# What form of accommodation does the school operate?                                                                                  object
# Type of school                                                                                                                       object
# ...

# %%
X = obj_df.iloc[:,:-1].values
X
# Out:
# array([['Region 1', 'Kakamega County', 'BUTERE SUB-COUNTY', ..., 'No',
#         'No', 'No'],
#        ['Region 1', 'Kakamega County', 'BUTERE SUB-COUNTY', ..., 'No',
#         'Yes', 'Yes'],
#        ['Region 1', 'West Pokot County', 'POKOT SOUTH SUB-COUNTY', ...,
#         'No', 'No', 'No'],
#        ...,
#        ['Region 1', 'Kisii County', 'NYAMACHE SUB-COUNTY', ..., 'No',
#         'No', 'No'],
#        ['Region 1', 'Kisii County', 'NYAMACHE SUB-COUNTY', ..., 'No',
#         'No', 'No'],
#        ['Region 1', 'Kisii County', 'NYAMACHE SUB-COUNTY', ..., 'No',
#         'No', 'No']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lblencode = LabelEncoder()
X[:,0] = lblencode.fit_transform(X[:,:-1])
X
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-cf101f93e356> in <module>()
#       3 from sklearn.preprocessing import LabelEncoder
#       4 lblencode = LabelEncoder()
# ----> 5 X[:,0] = lblencode.fit_transform(X[:,:-1])
#       6 X
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     249         y : array-like of shape [n_samples]
#     250         """
# --> 251         y = column_or_1d(y, warn=True)
#     252         self.classes_, y = _encode(y, encode=True)
#     253         return y
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#     795         return np.ravel(y)
#     796
# --> 797     raise ValueError("bad input shape {0}".format(shape))
#     798
#     799
#
# ValueError: bad input shape (1207, 28)

# %%
# using sklearn-pandas package
from sklearn_pandas import CategoricalImputer
 
# handling NaN values
imputer = CategoricalImputer()
data = np.array(obj_df, dtype=object)
imputer.fit_transform(data)
# Out:
# array([['Region 1', 'Kakamega County', 'BUTERE SUB-COUNTY', ..., 'No',
#         'No', 'No'],
#        ['Region 1', 'Kakamega County', 'BUTERE SUB-COUNTY', ..., 'Yes',
#         'Yes', 'No'],
#        ['Region 1', 'West Pokot County', 'POKOT SOUTH SUB-COUNTY', ...,
#         'No', 'No', 'No'],
#        ...,
#        ['Region 1', 'Kisii County', 'NYAMACHE SUB-COUNTY', ..., 'No',
#         'No', 'No'],
#        ['Region 1', 'Kisii County', 'NYAMACHE SUB-COUNTY', ..., 'No',
#         'No', 'No'],
#        ['Region 1', 'Kisii County', 'NYAMACHE SUB-COUNTY', ..., 'No',
#         'No', 'No']], dtype=object)

# %%
data.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-2962204f287d> in <module>()
# ----> 1 data.isnull().sum()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isnull'
