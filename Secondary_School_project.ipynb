# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaeljane/Secondary-school-data-analysis/blob/main/Secondary_School_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #import standard library 

#data analysis
import pandas as pd

#plotting
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px
# Read csv
df=pd.read_csv("/content/2019 Secondary Schools - Data.csv")

# %%
# read top rows
df.head()
# Out:
#      Region  ... Total number of beds
# 0  Region 1  ...                 61.0
# 1  Region 1  ...                430.0
# 2  Region 1  ...                215.0
# 3  Region 1  ...                  0.0
# 4  Region 1  ...                  0.0
#
# [5 rows x 401 columns]

# %%
# print rows and columns 
df.shape
# Out:
# (1445, 401)

# %%
#summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Columns: 401 entries, Region to Total number of beds
# dtypes: float64(97), int64(10), object(294)
# memory usage: 4.4+ MB

# %%
# name of the columns 
df.columns.values
# Out:
# array(['Region', 'Name of County', 'Name of Sub- County',
#        'Name of School', 'School Code (MoE)', "School's P.O. Box number",
#        'What is the school category',
#        'What is the gender of the students?',
#        'What form of accommodation does the school operate?',
#        'Type of school', 'Location of school',
#        'What is the name of nearest Trading Centre',
#        'What is the distance from the  school to nearest Trading Centre',
#        'What is the longest distance that day students walk to the school (one way)?',
#        'What is the longest time taken by day students to walk to school (one way)? ',
#        'Did the school receive any funding in the year 2017 or 2018?',
#        'Total income for 2018: ', 'Total income for 2017: ',
#        'How many KCSE candidates did the school have in 2018?',
#        'What was the overall school mean score in 2018?',
#        'What was MATHEMATICS  mean score in 2018?',
# ...

# %%
# Data types of columns
df.dtypes
# Out:
# Region                                            object
# Name of County                                    object
# Name of Sub- County                               object
# Name of School                                    object
# School Code (MoE)                                 object
#                                                   ...
# Total Dormitory Floor area                       float64
# The total Floor area of Permanent dormitories    float64
# Temporary Dormitory                              float64
# Inadequate and overcrowded  dormitories          float64
# Total number of beds                             float64
# Length: 401, dtype: object

# %%
#check null value 
df.isnull().sum()
# Out:
# Region                                            0
# Name of County                                    0
# Name of Sub- County                               0
# Name of School                                    0
# School Code (MoE)                                62
#                                                  ..
# Total Dormitory Floor area                        2
# The total Floor area of Permanent dormitories     3
# Temporary Dormitory                               1
# Inadequate and overcrowded  dormitories           5
# Total number of beds                              6
# Length: 401, dtype: int64

# %%
#summary of the data
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1440 entries, 0 to 1444
# Data columns (total 32 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Name of County                                                1440 non-null   int8
#  1   Name of School                                                1440 non-null   int16
#  2   What is the school category                                   1440 non-null   int8
#  3   What is the gender of the students?                           1440 non-null   int8
#  4   What form of accommodation does the school operate?           1440 non-null   int8
#  5   Type of school                                                1440 non-null   int8
#  6   Location of school                                            1440 non-null   int8
# ...

# %%
#checking the data types
df2.dtypes
# Out:
# Name of County                                                   int8
# Name of School                                                  int16
# What is the school category                                      int8
# What is the gender of the students?                              int8
# What form of accommodation does the school operate?              int8
# Type of school                                                   int8
# Location of school                                               int8
# How many KCSE candidates did the school have in 2018?           int16
# What was the overall school mean score in 2018?                 int16
# How many KCSE candidates did the school have in 2017?           int16
# What was the overall school mean score in 2017?                 int16
# How many classrooms are there in school?                        int64
# How many science laboratories are there?                        int64
# ...

# %%
# check the total  number of missing  value 
df2.isnull().sum()
# Out:
# Name of County                                           0
# Name of School                                           0
# What is the school category                              0
# What is the gender of the students?                      0
# What form of accommodation does the school operate?      0
# Type of school                                           0
# Location of school                                       4
# How many KCSE candidates did the school have in 2018?    2
# What was the overall school mean score in 2018?          2
# How many KCSE candidates did the school have in 2017?    2
# What was the overall school mean score in 2017?          2
# How many classrooms are there in school?                 0
# How many science laboratories are there?                 0
# Does the school have a library?                          1
# Does the school have Dormitories?                        1
# Does the school have Smart Classrooms                    1
# ...

# %%
# To see them in context
df2[df2.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
# Out:
#       Name of County  ... Does the school have ICT laboratories / Room?
# 0  West Pokot County  ...                                            No
# 1    Kakamega County  ...                                            No
# 2     Turkana County  ...                                           Yes
# 3    Kakamega County  ...                                           Yes
# 4    Kakamega County  ...                                            No
#
# [5 rows x 17 columns]

# %%
#Let's convert all the categorical variables into dummy variables
for column in [['Name of County', 'What is the gender of the students?', 'What is the school category', 'What form of accommodation does the school operate?', 'Type of school', 'Location of school', 'Does the school have a library?', 'Does the school have Dormitories?',	'Does the school have Smart Classrooms',	'Does the school have ICT laboratories / Room?']]:
    dummies = pd.get_dummies(df[column])
    df[dummies.columns] = dummies

# show  the first 5 rows 
df_dummies.head()
# Out:
#    Name of School  ...  Does the school have ICT laboratories / Room?_2
# 0             408  ...                                                0
# 1             689  ...                                                0
# 2             672  ...                                                1
# 3              70  ...                                                1
# 4              98  ...                                                0
#
# [5 rows x 80 columns]

# %%
#Get Correlation of "What was the overall school mean score in 2018?" with other variables:

# create a figure of size 15 width and 8 height 
plt.figure(figsize=(15,8))

# bar chart displaying  correration  and sort from highest feature that  affect churn 

df_dummies.corr()['What was the overall school mean score in 2018?'].sort_values(ascending = False).plot(kind='bar')
